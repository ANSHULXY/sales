# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime as dt

file = pd.read_csv('statsfinal.csv')

# %%
file.head(110)
# Out:
#      Unnamed: 0                          Date  Q-P1  Q-P2  Q-P3  Q-P4  \
# 0             0 2010-06-13 00:00:00.000000000  5422  3725   576   907
# 1             1 2010-06-14 00:00:00.000000000  7047   779  3578  1574
# 2             2 2010-06-15 00:00:00.000000000  1572  2082   595  1145
# 3             3 2010-06-16 00:00:00.000000000  5657  2399  3140  1672
# 4             4 2010-06-17 00:00:00.000000000  3668  3207  2184   708
# ..          ...                           ...   ...   ...   ...   ...
# 105         105 2010-09-27 00:00:00.000000000  2596  1820   760  1253
# 106         106 2010-09-28 00:00:00.000000000  1068  2055   715  1087
# 107         107 2010-09-29 00:00:00.000000000  5110  3370  1228  1871
# 108         108 2010-09-30 00:00:00.000000000  7642  3158   414   656
# 109         109 2016-10-07 03:11:43.629208576  4986   342  4978   558
#
#          S-P1      S-P2      S-P3      S-P4
# 0    17187.74  23616.50   3121.92   6466.91
# ...

# %%
**understand the data

# %%
file.shape
file.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Q-P1', 'Q-P2', 'Q-P3', 'Q-P4', 'S-P1', 'S-P2',
#        'S-P3', 'S-P4'],
#       dtype='object')

# %%
file.isnull().sum()
# Out:
# Unnamed: 0    0
# Date          0
# Q-P1          0
# Q-P2          0
# Q-P3          0
# Q-P4          0
# S-P1          0
# S-P2          0
# S-P3          0
# S-P4          0
# dtype: int64

# %%
NO NULL UALUES ARE THERE

# %%
file.dtypes
# Out:
# Unnamed: 0      int64
# Date           object
# Q-P1            int64
# Q-P2            int64
# Q-P3            int64
# Q-P4            int64
# S-P1          float64
# S-P2          float64
# S-P3          float64
# S-P4          float64
# dtype: object

# %%
file.duplicated().sum()
# Out:
# 0

# %%
file.describe().T
# Out:
#              count          mean          std      min       25%        50%  \
# Unnamed: 0  4600.0   2299.500000  1328.049949     0.00  1149.750   2299.500
# Q-P1        4600.0   4121.849130  2244.271323   254.00  2150.500   4137.000
# Q-P2        4600.0   2130.281522  1089.783705   251.00  1167.750   2134.000
# Q-P3        4600.0   3145.740000  1671.832231   250.00  1695.750   3202.500
# Q-P4        4600.0   1123.500000   497.385676   250.00   696.000   1136.500
# S-P1        4600.0  13066.261743  7114.340094   805.18  6817.085  13114.290
# S-P2        4600.0  13505.984848  6909.228687  1591.34  7403.535  13529.560
# S-P3        4600.0  17049.910800  9061.330694  1355.00  9190.965  17357.550
# S-P4        4600.0   8010.555000  3546.359869  1782.50  4962.480   8103.245
#
#                   75%       max
# Unnamed: 0   3449.250   4599.00
# Q-P1         6072.000   7998.00
# Q-P2         3070.250   3998.00
# Q-P3         4569.000   6000.00
# Q-P4         1544.000   2000.00
# ...

# %%
file[file['Date'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Date, Q-P1, Q-P2, Q-P3, Q-P4, S-P1, S-P2, S-P3, S-P4]
# Index: []

# %%
file['Date']= pd.to_datetime(file['Date'],errors='coerce')

# %%
file[file['Date'].isnull()]
# Out:
#       Unnamed: 0 Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2      S-P3  \
# 109          109  NaT  4986   342  4978   558  15805.62   2168.28  26980.76
# 170          170  NaT  4632  3930   523  1581  14683.44  24916.20   2834.66
# 473          473  NaT  2242   401  5926   789   7107.14   2542.34  32118.92
# 534          534  NaT   325  3476  4588  1771   1030.25  22037.84  24866.96
# 836          836  NaT  1003   256  1346  1449   3179.51   1623.04   7295.32
# 897          897  NaT  2509  2666  4146   593   7953.53  16902.44  22471.32
# 1200        1200  NaT   597   709  5470  1994   1892.49   4495.06  29647.40
# 1261        1261  NaT  7681  1235   347  1087  24348.77   7829.90   1880.74
# 1564        1564  NaT  5333   833  3494   618  16905.61   5281.22  18937.48
# 1625        1625  NaT  3870  2779  3246  1290  12267.90  17618.86  17593.32
# 1928        1928  NaT  3583  2111  4225  1401  11358.11  13383.74  22899.50
# ...

# %%
#  Filling the NaT  values with average of time

# %%
file["Date"].fillna(file["Date"].mean(),inplace=True)

# %%
file[file['Date'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Date, Q-P1, Q-P2, Q-P3, Q-P4, S-P1, S-P2, S-P3, S-P4]
# Index: []

# %%
file[file['Unnamed: 0']==1261]
# Out:
#       Unnamed: 0                          Date  Q-P1  Q-P2  Q-P3  Q-P4  \
# 1261        1261 2016-10-07 03:11:43.629208576  7681  1235   347  1087
#
#           S-P1    S-P2     S-P3     S-P4
# 1261  24348.77  7829.9  1880.74  7750.31

# %%
#fetching month,day of week, weekday
file["month"]=file["Date"].dt.month_name()
file["day"]=file["Date"].dt.day_name()
file["dayoftheweek"]=file["Date"].dt.weekday
file["year"]=file["Date"].dt.year

# %%
file.head()
# Out:
#    Unnamed: 0       Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2  \
# 0           0 2010-06-13  5422  3725   576   907  17187.74  23616.50
# 1           1 2010-06-14  7047   779  3578  1574  22338.99   4938.86
# 2           2 2010-06-15  1572  2082   595  1145   4983.24  13199.88
# 3           3 2010-06-16  5657  2399  3140  1672  17932.69  15209.66
# 4           4 2010-06-17  3668  3207  2184   708  11627.56  20332.38
#
#        S-P3      S-P4 month        day  dayoftheweek  year
# 0   3121.92   6466.91  June     Sunday             6  2010
# 1  19392.76  11222.62  June     Monday             0  2010
# 2   3224.90   8163.85  June    Tuesday             1  2010
# 3  17018.80  11921.36  June  Wednesday             2  2010
# 4  11837.28   5048.04  June   Thursday             3  2010

# %%
## Droping column unnamed as it is not usefull for us

# %%
file.drop(columns=["Unnamed: 0"],inplace=True)

# %%
file.sample()
# Out:
#           Date  Q-P1  Q-P2  Q-P3  Q-P4     S-P1      S-P2      S-P3     S-P4  \
# 303 2011-04-13  3096  1732  2198   607  9814.32  10980.88  11913.16  4327.91
#
#      month        day  dayoftheweek  year
# 303  April  Wednesday             2  2011

# %%
plt.figure(figsize=(10,10))
sns.heatmap(file.corr(),annot=True)
# Out:
# /var/folders/ws/wcwkybw522v8l5gbbl24kn_40000gn/T/ipykernel_43891/3681126328.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(file.corr(),annot=True)
# <Axes: >

# %%
#no two colum has a good relation

# %%
# Total unit sales Product 1, Product 2, Product 3, Product 4 
q = file[["Q-P1","Q-P2","Q-P3","Q-P4"]].sum()
print(q)
plt.figure(figsize=(8,8))
plt.pie(q,labels=file[["Q-P1","Q-P2","Q-P3","Q-P4"]].sum().index,shadow=True,autopct="%0.01f%%",textprops={"fontsize":20},wedgeprops={'width': 0.8},explode=[0,0,0,0.3])
plt.legend(loc='center right', bbox_to_anchor=(1.2, 0.8));
# Out:
# Q-P1    18960506
# Q-P2     9799295
# Q-P3    14470404
# Q-P4     5168100
# dtype: int64

# %%
# Total Revenue percent from sales from Product 1, Product 2, Product 3, Product 4  
s=file[["S-P1","S-P2","S-P3","S-P4"]].sum()
print(s)
plt.figure(figsize=(8,8))
plt.pie(s,labels=file[["S-P1","S-P2","S-P3","S-P4"]].sum().index,shadow=True,autopct="%0.01f%%",textprops={"fontsize":20},wedgeprops={'width': 0.8},explode=[0,0,0,0.3])
plt.legend(loc='center right', bbox_to_anchor=(1.2, 0.8))
# Out:
# S-P1    60104804.02
# S-P2    62127530.30
# S-P3    78429589.68
# S-P4    36848553.00
# dtype: float64

# %%
# sales according to months
print(file["month"].value_counts())
plt.figure(figsize=(10,10))
sns.countplot(x="month",data=file,edgecolor="black")
plt.xticks(rotation=90);
# Out:
# October      411
# January      399
# July         398
# June         385
# August       385
# September    385
# November     385
# December     385
# March        380
# May          379
# April        367
# February     341
# Name: month, dtype: int64

# %%
# which is the most occuring Day 
print(file["day"].value_counts())
plt.figure(figsize=(10,10))
sns.countplot(x="day",data=file,edgecolor="black")
plt.xticks(rotation=90);
# Out:
# Friday       680
# Wednesday    655
# Sunday       654
# Thursday     654
# Tuesday      653
# Monday       652
# Saturday     652
# Name: day, dtype: int64

# %%
# which is the most occuring year 
print(file["year"].value_counts())
plt.figure(figsize=(10,10))
sns.countplot(x="year",data=file,edgecolor="black")
plt.xticks(rotation=90);
# Out:
# 2016    387
# 2011    362
# 2013    362
# 2014    362
# 2015    362
# 2017    362
# 2018    362
# 2019    362
# 2021    362
# 2022    362
# 2012    361
# 2020    361
# 2010    199
# 2023     34
# Name: year, dtype: int64

# %%
# Monthly distrubution of revenue 
sns.relplot(x="month",y="S-P1",data=file,kind="line",height=10,color="red")
plt.xticks(rotation=90);
sns.relplot(x="month",y="S-P2",data=file,kind="line",height=10,color="blue")
plt.xticks(rotation=90);
sns.relplot(x="month",y="S-P3",data=file,kind="line",height=10,color="green")
plt.xticks(rotation=90);
sns.relplot(x="month",y="S-P4",data=file,kind="line",height=10,color="purple")
plt.xticks(rotation=90);

# %%
## In which month revenue was it peak
file.groupby("month")[["S-P1","S-P2","S-P3","S-P4"]].sum()
# Out:
#                  S-P1        S-P2        S-P3        S-P4
# month
# April      4994236.73  5074402.86  6218523.18  2970628.94
# August     5032438.40  5327280.10  6545224.52  3058499.06
# December   5140424.45  5218441.32  6457398.84  3102797.75
# February   4576731.88  4561845.56  6042134.70  2613444.46
# January    5048012.61  5360970.86  6693223.04  3228692.16
# July       5205647.20  5199104.32  6732490.94  3142091.18
# June       5251837.27  5226404.36  6574600.92  3142454.81
# March      4786119.89  5332035.10  6440791.96  3098619.57
# May        4983870.83  5207752.08  6722008.66  3006278.94
# November   4813933.47  5119068.16  6508476.92  3168215.50
# October    5454847.24  5472326.62  6840809.64  3221134.36
# September  4816704.05  5027898.96  6653906.36  3095696.27

# %%
plt.figure(figsize=(15,15),dpi=100)
plt.subplot(2,2,1)
sns.barplot(x="month",y="S-P1",data=file,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,2)
sns.barplot(x="month",y="S-P2",data=file,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,3)
sns.barplot(x="month",y="S-P3",data=file,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,4)
sns.barplot(x="month",y="S-P4",data=file,edgecolor="black",estimator=sum)
plt.xticks(rotation=90)
plt.subplots_adjust(hspace=0.3);

# %%
plt.figure(figsize=(15,15),dpi=100)
plt.subplot(2,2,1)
sns.barplot(x="month",y="Q-P1",data=file,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,2)
sns.barplot(x="month",y="Q-P2",data=file,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,3)
sns.barplot(x="month",y="Q-P3",data=file,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,4)
sns.barplot(x="month",y="Q-P4",data=file,edgecolor="black",estimator=sum)
plt.xticks(rotation=90)
plt.subplots_adjust(hspace=0.3);

# %%
# weekly analysis
week_t=file[file["dayoftheweek"]<5]
weekend_t=file[file["dayoftheweek"]>=5]
print(week_t.groupby("day")[["S-P1","S-P2","S-P3","S-P4"]].sum())
# Out:
#                  S-P1        S-P2         S-P3        S-P4
# day
# Friday     8913637.41  9267831.02  11428877.58  5463169.99
# Monday     8636791.80  8864347.08  11064892.06  5292577.61
# Thursday   8577981.96  8909481.54  10951554.44  5043013.35
# Tuesday    8433525.06  8738326.90  11156338.30  5384854.07
# Wednesday  8693537.97  8908067.72  11017830.20  5086827.20

# %%
plt.figure(figsize=(10,10),dpi=100)
plt.subplot(2,2,1)
sns.barplot(x="day",y="S-P1",data=week_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45);
plt.subplot(2,2,2)
sns.barplot(x="day",y="S-P2",data=week_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45);
plt.subplot(2,2,3)
sns.barplot(x="day",y="S-P3",data=week_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45);
plt.subplot(2,2,4)
sns.barplot(x="day",y="S-P4",data=week_t,edgecolor="black",estimator=sum)
plt.xticks(rotation=45)
plt.subplots_adjust(hspace=0.5);

# %%
# In which year revenue was the highest 
file.groupby("year")[["S-P1","S-P2","S-P3","S-P4"]].agg(["sum"])
# Out:
#             S-P1        S-P2        S-P3        S-P4
#              sum         sum         sum         sum
# year
# 2010  2543459.01  2720100.92  3385462.08  1567523.37
# 2011  4542819.22  4741147.10  6235075.86  2921603.06
# 2012  4771163.83  4861987.50  6173911.16  2965210.14
# 2013  4833682.57  4771369.88  6017809.74  2868491.69
# 2014  4954522.97  4979797.38  6265406.18  2865119.20
# 2015  4669720.66  4833806.20  5987988.90  2933224.96
# 2016  5096066.64  5313116.54  6507718.12  3096444.92
# 2017  4628545.53  5085909.96  6269568.74  2969944.46
# 2018  4825792.44  4727313.22  6198517.96  2824392.64
# 2019  4681354.56  4946303.16  6106237.04  2912519.44
# 2020  4732093.58  4904826.88  6343643.88  2984618.00
# 2021  4758100.26  4948382.68  6294208.06  2894394.98
# 2022  4591000.05  4797040.54  5993479.36  2760400.89
# 2023   476482.70   496428.34   650562.60   284665.25

# %%
plt.figure(figsize=(10,10),dpi=100)
plt.subplot(2,2,1)
sns.barplot(x="year",y="S-P1",data=file,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,2)
sns.barplot(x="year",y="S-P2",data=file,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,3)
sns.barplot(x="year",y="S-P3",data=file,edgecolor="black",estimator=sum)
plt.xticks(rotation=90);
plt.subplot(2,2,4)
sns.barplot(x="year",y="S-P4",data=file,edgecolor="black",estimator=sum)
plt.xticks(rotation=90)
plt.subplots_adjust(hspace=0.5);

# %%
file.tail()
# Out:
#            Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2      S-P3  \
# 4595 2023-01-30  2476  3419   525  1359   7848.92  21676.46   2845.50
# 4596 2023-01-31  7446   841  4825  1311  23603.82   5331.94  26151.50
# 4597 2023-01-02  6289  3143  3588   474  19936.13  19926.62  19446.96
# 4598 2023-02-02  3122  1188  5899   517   9896.74   7531.92  31972.58
# 4599 2023-03-02  1234  3854  2321   406   3911.78  24434.36  12579.82
#
#          S-P4     month       day  dayoftheweek  year
# 4595  9689.67   January    Monday             0  2023
# 4596  9347.43   January   Tuesday             1  2023
# 4597  3379.62   January    Monday             0  2023
# 4598  3686.21  February  Thursday             3  2023
# 4599  2894.78     March  Thursday             3  2023
